# %% [markdown]
# # Step1: Install Librarys

# %%
# !pip install wikipedia
# !pip install pyspark
# Out:
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# # Step2: Import Librarys

# %%
import wikipedia
import pyspark
import os
import sys
import shutil
import re

# %% [markdown]
# # Step3: get wikipedia dataset

# %%
dataset1 = wikipedia.page('Python (programming language)').content
dataset2 = ["to be or not to be this is the problem"]

dataset1 = re.sub(r'[\n\t]', ' ', dataset1)
dataset1 = re.sub(r'\s+', ' ', dataset1.strip())
dataset1 = [dataset1]

# %% [markdown]
# # Step4: Define Ngram functions

# %%
def ngrams(line, N):
    words = line.split()
    ngrams = [tuple(words[i:i+N]) for i in range(len(words)-N+1)]
    return ngrams

def generate_ngrams(rdd, n):
    rdd = rdd.flatMap(lambda line: ngrams(line, n))\
             .map(lambda ngram: (ngram, 1))\
             .reduceByKey(lambda x, y: x + y)\
             .sortBy(lambda x: x[1], ascending=False)
    return rdd

# %% [markdown]
# # Step5: Set Paths

# %%
home = "/content/"
log = home + "log/"
output_dir = home + "output.txt"

# %% [markdown]
# # Step6: Make directory for log folder

# %%
path = "/content/log"
os.makedirs(path, exist_ok=True)

# %% [markdown]
# # Step7: set vaiables

# %%
worker_count = 2
file_size = sys.getsizeof(dataset2)
partition_size = 30
partition_count = int(file_size / partition_size)

# %% [markdown]
# # Step8: Manage and configure the SparkContext

# %%
conf = pyspark.SparkConf()\
 .setAppName("word_counter")\
 .set("spark.eventLog.enabled", "true") \
 .set("spark.eventLog.dir", log) \
 .setMaster("local[" + str(worker_count) + "]")

spark = pyspark.sql.SparkSession.builder\
 .config("spark.executor.memory", "10g") \
 .config("spark.driver.memory", "10g") \
 .config(conf=conf).getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# # Step9: Run the program

# %%
rdd = sc.parallelize(dataset1)
counts = generate_ngrams(rdd, 2)
words = counts.collect()
print(words)
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)

counts.coalesce(1).saveAsTextFile(output_dir)
# Out:
# [(('of', 'the'), 36), (('in', 'the'), 24), (('is', 'a'), 19), (('of', 'Python'), 19), (('such', 'as'), 18), (('as', 'a'), 15), (('be', 'used'), 15), (('to', 'the'), 14), (('Python', 'is'), 13), (('to', 'be'), 13), (('can', 'be'), 13), (('the', 'Python'), 13), (('in', 'Python'), 12), (('from', 'the'), 11), (('statement,', 'which'), 11), (('with', 'the'), 10), (('used', 'to'), 10), (('to', 'a'), 9), (('with', 'a'), 8), (('Python', 'uses'), 8), (('standard', 'library'), 8), (('part', 'of'), 8), (('and', 'a'), 7), (('the', 'same'), 7), (('to', 'Python'), 7), (('Python', 'has'), 7), (('programming', 'languages'), 7), (('used', 'in'), 7), (('as', 'the'), 7), (('of', 'a'), 7), (('written', 'in'), 7), (('subset', 'of'), 7), (('will', 'be'), 6), (('Python', '2.7'), 6), (('and', 'is'), 6), (('use', 'of'), 6), (('by', 'the'), 6), (('Python', '3'), 6), (('Python', '3.12'), 6), (('is', 'also'), 6), (('it', 'is'), 6), (('may', 'be'), 6), (('It', 'is'), 6), (('and', 'the'), 6), (('==', 'Python'), 5), (('for', 'the'), 5), (('has', 'a'), 5), (('does', 'not'), 5), (('the', 'standard'), 5), (('Python', 'as'), 5), (('in', 'a'), 5), (('are', 'not'), 5), (('a', 'scripting'), 5), (('rather', 'than'), 5), (('scripting', 'language'), 5), (('a', 'subset'), 5), (('Guido', 'van'), 5), (('released', 'in'), 5), (('on', 'the'), 5), (('Python', 'to'), 5), (('that', 'the'), 4), (('is', 'used'), 4), (('the', 'use'), 4), (('was', 'released'), 4), (('many', 'other'), 4), (('better', 'than'), 4), (('to', 'other'), 4), (('==', "Python's"), 4), (('with', 'Python'), 4), (('release', 'in'), 4), (('the', 'version'), 4), (('(latest', 'release'), 4), (('as', 'of'), 4), (('of', 'its'), 4), (('is', 'the'), 4), (('is', 'not'), 4), (('possible', 'to'), 4), (('uses', 'the'), 4), (('number', 'of'), 4), (('version', 'number'), 4), (('number', 'is'), 4), (('programming', 'language'), 4), (('Python,', 'a'), 4), (('used', 'as'), 4), (('van', 'Rossum'), 4), (('is', 'better'), 4), (('contrast', 'to'), 4), (('a', 'Python'), 4), (('example,', 'the'), 4), (('to', 'machine'), 4), (('code', 'is'), 4), (('Python', 'in'), 3), (('and', 'has'), 3), (('use', 'in'), 3), (('out', 'of'), 3), (('removed', 'in'), 3), (('other', 'languages,'), 3), (('executes', 'a'), 3), (('block', 'of'), 3), (('a', 'generator'), 3), (('is', 'possible'), 3), (('Perl,', 'and'), 3), (('compiles', 'a'), 3), (('in', 'Python.'), 3), (('of', 'programming'), 3), (('Archived', 'from'), 3), (('the', 'original'), 3), (('Python', '2'), 3), (('be', 'removed'), 3), (('to', 'do'), 3), (('by', 'using'), 3), (('other', 'languages'), 3), (('the', 'current'), 3), (('similar', 'to'), 3), (('There', 'are'), 3), (('(1,', '2,'), 3), (('which', 'is'), 3), (('use', 'the'), 3), (('are', 'also'), 3), (('syntax,', 'and'), 3), (('Python', 'and'), 3), (('a', 'similar'), 3), (('most', 'popular'), 3), (('Python', 'community'), 3), (('the', 'language,'), 3), (('also', 'has'), 3), (('use', 'Python'), 3), (('===', 'Python'), 3), (('from', 'a'), 3), (('in', 'Python:'), 3), (('many', 'of'), 3), (('because', 'of'), 3), (('It', 'also'), 3), (('and', 'more'), 3), (('of', 'their'), 3), (('support', 'for'), 3), (('large', 'standard'), 3), (('in', 'its'), 3), (('Monty', 'Python'), 3), (('a', 'block'), 3), (('code', 'block'), 3), (('a', 'value'), 3), (('floor', 'division'), 3), (('written', 'as'), 3), (('cannot', 'be'), 3), (('Python', 'can'), 3), (('and', 'negative'), 3), (('often', 'used'), 3), (('used', 'for'), 3), (('means', 'that'), 3), (('compiles', 'Python'), 3), (("Python's", 'development'), 3), (('and', 'many'), 3), (('(for', 'example,'), 3), (('In', 'Python,'), 3), (('operator', 'for'), 3), (('of', 'this'), 3), (('b', 'is'), 3), (('is', 'incremented.'), 3), (('original', 'on'), 3), (('due', 'to'), 3), (('one', 'of'), 3), (('a', 'large'), 3), (('It', 'has'), 3), (('statement,', 'used'), 3), (('they', 'are'), 3), (('Its', 'design'), 2), (('ABC', 'programming'), 2), (('Python', '2.0'), 2), (('machine', 'learning'), 2), (('major', 'new'), 2), (('list ...

# %% [markdown]
# # Step10: Clean the Garbage files

# %%
# !mv "/content/output.txt/part-00000" "/content/result.txt"

# %%
# !rm -r "/content/output.txt"
